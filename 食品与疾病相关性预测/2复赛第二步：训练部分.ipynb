# %% [markdown]
# ## 模型训练

# %%
import pandas as pd
import os
import gc
import lightgbm as lgb
from sklearn.preprocessing import MinMaxScaler
import math
import numpy as np
from tqdm import tqdm
from sklearn.model_selection import StratifiedKFold, KFold, GroupKFold
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, log_loss
import matplotlib.pyplot as plt
import time
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 导入数据

# %%
disease_feature1 = pd.read_csv("/home/mw/input/data8766/训练集/训练集/disease_feature1.csv")
disease_feature2 = pd.read_csv("/home/mw/input/data8766/训练集/训练集/disease_feature2.csv")
disease_feature3 = pd.read_csv("/home/mw/input/data8766/训练集/训练集/disease_feature3.csv")

train_answer = pd.read_csv("/home/mw/input/data8766/训练集/训练集/train_answer.csv")
train_food = pd.read_csv("/home/mw/input/data8766/训练集/训练集/train_food.csv")
semi_train_answer = pd.read_csv("/home/mw/input/data6690/semi_train_answer.csv")
semi_train_answer
# Out:
#         food_id    disease_id  related_score
# 0        food_0   disease_208              0
# 1        food_0  disease_1166              0
# 2        food_0  disease_1418              0
# 3        food_0    disease_76              0
# 4        food_0   disease_579              0
# ...         ...           ...            ...
# 141631  food_97   disease_685              0
# 141632  food_97   disease_325              0
# 141633  food_97   disease_911              0
# 141634  food_97   disease_961              0
# 141635  food_97  disease_1326              0
#
# [141636 rows x 3 columns]

# %%
data = semi_train_answer
data.head()
# Out:
#   food_id    disease_id  related_score
# 0  food_0   disease_208              0
# 1  food_0  disease_1166              0
# 2  food_0  disease_1418              0
# 3  food_0    disease_76              0
# 4  food_0   disease_579              0

# %% [markdown]
# ### 食物、疾病特征编码

# %%
data['food'] = data['food_id'].apply(lambda x : int(x.split('_')[1]))
data['disease'] = data['disease_id'].apply(lambda x : int(x.split('_')[1]))

# %% [markdown]
# ### 定义峰度、偏度函数，方便后续调用进行计算

# %%
def skew(x): return x.skew()
def kurtosis(x): return x.kurtosis()

# %% [markdown]
# ### 按照疾病ID分组，计算每个疾病与所有食物的相关性的四个统计量（均值、标准差、偏度、峰度）

# %%
# 定义一个列表，包含需要进行统计的列名
cat_list = ['disease']

# 定义一个函数，对数据进行统计
def stat(df, df_merge, group_by, agg):
    # 对数据进行分组，并进行聚合操作
    group = df.groupby(group_by).agg(agg)

    # 生成新的列名
    columns = []
    for on, methods in agg.items():
        for method in methods:
            if method == kurtosis:
                method = 'kurtosis'
            elif method == skew:
                method = 'skew'
            columns.append('{}_{}_{}'.format('_'.join(group_by), on, method))
        group.columns = columns
        group.reset_index(inplace=True)
        df_merge = df_merge.merge(group, on=group_by, how='left')

    # 删除变量，释放内存
    del (group)
    gc.collect()
    return df_merge

# 对数据进行预处理
df_train = data[~data['related_score'].isnull()]
df_train = df_train.reset_index(drop=True)

# 对数据进行统计
df_stas_feat = stat(df_train, df_train, cat_list, {'related_score': ['mean','std',skew, kurtosis]})

data = pd.concat([df_stas_feat], axis=0)
data = data.reset_index(drop=True)

del (df_stas_feat)
del (df_train)

# %%
data
# Out:
#         food_id    disease_id  related_score  food  disease  \
# 0        food_0   disease_208              0     0      208
# 1        food_0  disease_1166              0     0     1166
# 2        food_0  disease_1418              0     0     1418
# 3        food_0    disease_76              0     0       76
# 4        food_0   disease_579              0     0      579
# ...         ...           ...            ...   ...      ...
# 141631  food_97   disease_685              0    97      685
# 141632  food_97   disease_325              0    97      325
# 141633  food_97   disease_911              0    97      911
# 141634  food_97   disease_961              0    97      961
# 141635  food_97  disease_1326              0    97     1326
#
#         disease_related_score_mean  disease_related_score_std  \
# 0                         0.000000                   0.000000
# 1                         0.000000                   0.000000
# 2                         0.008621                   0.160817
# 3                         0.103448                   0.558600
# 4                         0.000000                   0.000000
# ...                            ...                        ...
# 141631                    0.034483                   0.237580
# 141632                    0.347701                   0.970647
# 141633                    0.000000                   0.000000
# 141634                    0.540230                   0.921152
# 141635                    0.103448                   0.492818
#
#         disease_related_score_skew  disease_related_score_kurtosis
# 0                         0.000000                        0.000000
# 1                         0.000000                        0.000000
# 2                        18.654758                      348.000000
# 3                         5.820405                       34.080231
# 4                         0.000000                        0.000000
# ...                            ...                             ...
# 141631                    8.637006                       87.485497
# 141632                    2.565232                        4.931675
# 141633                    0.000000                        0.000000
# 141634                    1.527621                        1.146513
# 141635                    5.605177                       33.896142
#
# [141636 rows x 9 columns]

# %%
data.head()
drms = data[['disease_id','disease_related_score_mean','disease_related_score_std','disease_related_score_skew','disease_related_score_kurtosis']]
drms_unique = drms.drop_duplicates(subset=['disease_id'])
drms_unique.to_csv('best_model/drms_unique.csv', index=False)

# %% [markdown]
# ### 对三组疾病特征进行PCA降维
# 维度做过一些调整，最终选用群友Baseline给出的维度

# %%
from sklearn.decomposition import PCA,KernelPCA,TruncatedSVD,SparsePCA
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler,MinMaxScaler
SEED = 7
def pca_fea(data, feats, n_components=10, name='tsvd', load=False):

    tsvd = Pipeline([
        ('std', MinMaxScaler()),
        # ('tsvd', TruncatedSVD(n_components=n_components, n_iter=20, random_state=SEED)),
        # ('pca', SparsePCA(n_components=n_components, max_iter=200, random_state=SEED,alpha=0.1,n_jobs=8))
        ('pca', PCA(n_components=n_components, random_state=SEED))

    ])
    tsvd.fit(data[feats])
    data_id = data['disease_id']
    deal_data = pd.DataFrame(tsvd.transform(data[feats]), columns=[f'{name}_{i}' for i in range(n_components)])
    deal_data.insert(0, 'disease_id', data['disease_id'])
    return deal_data

# %%
n_disease_tsvd1 = 125
feat1 = pca_fea(
    disease_feature1, 
    [item for item in disease_feature1.columns if item not in ['disease_id']], 
    n_components=n_disease_tsvd1, 
    name='disease1_pca'
)
n_disease_tsvd2 = 220
feat2 = pca_fea(
    disease_feature2, 
    [item for item in disease_feature2.columns if item not in ['disease_id']], 
    n_components=n_disease_tsvd2, 
    name='disease2_pca'
)
n_disease_tsvd3 = 130
feat3 = pca_fea(
    disease_feature3, 
    [item for item in disease_feature3.columns if item not in ['disease_id']], 
    n_components=n_disease_tsvd3, 
    name='disease3_pca'
)

# %%
food = train_food
# drop_rate = 0.1
# per_mis = list(food.isnull().sum() / len(food))
# df_missing = pd.DataFrame({'列名': food.columns,'缺失率': per_mis})
# df_missing.sort_values('缺失率', inplace=True,ascending=False)
# miss_fea = list(df_missing[df_missing['缺失率']<=drop_rate]['列名'])
# print(len(miss_fea))
# miss_fea

# %% [markdown]
# ### 加载聚类模型进行聚类

# %%
miss_fea = ['N_197','N_198','N_33','N_211','N_82','N_111','N_165', 'N_101','N_177','N_42','N_146','N_113','N_17','N_106','N_14','N_74','N_209','N_188','food_id']

# %%
from sklearn.metrics import silhouette_score, silhouette_samples
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture
from sklearn.preprocessing import StandardScaler,MinMaxScaler
df_food = food[miss_fea]
df_food = df_food.drop(columns='food_id')
df_food = df_food.fillna(-1)
df_dis_1 = feat1.drop(columns='disease_id')
df_dis_2 = feat2.drop(columns='disease_id')
df_dis_3 = feat3.drop(columns='disease_id')

# %%
import joblib
mean = joblib.load('best_model/food_mean.pkl')
std = joblib.load('best_model/food_std.pkl')
df_food_st = (df_food - mean) / std
gmm_food = joblib.load('best_model/gmm_food_model.pkl')
food_clu = gmm_food.fit_predict(df_food_st)
food['food_clu'] = food_clu

# %%
gmm_d1 = joblib.load('best_model/gmm_d1_model.pkl')
d1_clu = gmm_d1.fit_predict(df_dis_1)
feat1['d1_clu'] = d1_clu

gmm_d2 = joblib.load('best_model/gmm_d2_model.pkl')
d2_clu = gmm_d2.fit_predict(df_dis_2)
feat2['d2_clu'] = d2_clu

gmm_d3 = joblib.load('best_model/gmm_d3_model.pkl')
d3_clu = gmm_d3.fit_predict(df_dis_3)
feat3['d3_clu'] = d3_clu

# %%
food['food_clu'].nunique()
# Out:
# 10

# %% [markdown]
# ### 数据进行拼接

# %%
data = data.merge(food, on = 'food_id', how = 'left')
data = data.merge(feat1, on = 'disease_id', how = 'left')
data = data.merge(feat2, on = 'disease_id', how = 'left')
data = data.merge(feat3, on = 'disease_id', how = 'left')
data.head()
# Out:
#   food_id    disease_id  related_score  food  disease  \
# 0  food_0   disease_208              0     0      208
# 1  food_0  disease_1166              0     0     1166
# 2  food_0  disease_1418              0     0     1418
# 3  food_0    disease_76              0     0       76
# 4  food_0   disease_579              0     0      579
#
#    disease_related_score_mean  disease_related_score_std  \
# 0                    0.000000                   0.000000
# 1                    0.000000                   0.000000
# 2                    0.008621                   0.160817
# 3                    0.103448                   0.558600
# 4                    0.000000                   0.000000
#
#    disease_related_score_skew  disease_related_score_kurtosis  N_0  ...  \
# 0                    0.000000                        0.000000  NaN  ...
# 1                    0.000000                        0.000000  NaN  ...
# 2                   18.654758                      348.000000  NaN  ...
# 3                    5.820405                       34.080231  NaN  ...
# 4                    0.000000                        0.000000  NaN  ...
#
#    disease3_pca_121  disease3_pca_122  disease3_pca_123  disease3_pca_124  \
# 0         -0.119260         -0.049350          0.023139         -0.113043
# 1          0.001666          0.087646         -0.079354         -0.012906
# 2         -0.079943         -0.059698          0.025662         -0.026360
# 3         -0.019461         -0.016764         -0.007335          0.029523
# 4          0.047630          0.014324          0.029200          0.112854
#
#    disease3_pca_125  disease3_pca_126  disease3_pca_127  disease3_pca_128  \
# 0         -0.049646         -0.030825          0.059619          0.054251
# 1          0.065473         -0.069966          0.001386          0.022145
# 2          0.050460          0.074278          0.022300          0.048073
# 3          0.055458         -0.014474         -0.098375          0.005207
# 4          0.014293         -0.073378         -0.107103         -0.054103
#
#    disease3_pca_129  d3_clu
# 0         -0.027106    31.0
# 1          0.021254    46.0
# 2         -0.031466    10.0
# 3          0.010734    10.0
# 4          0.099642    14.0
#
# [5 rows x 700 columns]

# %%
# data.groupby('d2_clu')['related_score'].apply(lambda x: (x > 0).sum())

# %% [markdown]
# ### 按照食物类别进行分组，计算每个食物类别与所有疾病的相关性的四个统计量（均值、方差、偏度、峰度）

# %%
food_r = data.groupby('food_clu').agg({'related_score': ['mean', 'var',skew, kurtosis]}).droplevel(0, axis=1).rename(columns={'mean': 'food_r_mean', 'var': 'food_r_var'}).reset_index()
food_r.head()
# Out:
#    food_clu  food_r_mean  food_r_var      skew   kurtosis
# 0         0     0.091203    0.202963  5.727235  35.200376
# 1         1     0.237439    0.561195  3.361275  10.718445
# 2         2     0.420259    0.815991  2.193714   3.943628
# 3         3     0.229156    0.544300  3.394388  10.944700
# 4         4     0.275184    0.600687  2.928936   7.889432

# %%
food_r.to_csv('best_model/food_r.csv', index=False)

# %%
data = data.merge(food_r, on = 'food_clu', how = 'left')
data.head()
# Out:
#   food_id    disease_id  related_score  food  disease  \
# 0  food_0   disease_208              0     0      208
# 1  food_0  disease_1166              0     0     1166
# 2  food_0  disease_1418              0     0     1418
# 3  food_0    disease_76              0     0       76
# 4  food_0   disease_579              0     0      579
#
#    disease_related_score_mean  disease_related_score_std  \
# 0                    0.000000                   0.000000
# 1                    0.000000                   0.000000
# 2                    0.008621                   0.160817
# 3                    0.103448                   0.558600
# 4                    0.000000                   0.000000
#
#    disease_related_score_skew  disease_related_score_kurtosis  N_0  ...  \
# 0                    0.000000                        0.000000  NaN  ...
# 1                    0.000000                        0.000000  NaN  ...
# 2                   18.654758                      348.000000  NaN  ...
# 3                    5.820405                       34.080231  NaN  ...
# 4                    0.000000                        0.000000  NaN  ...
#
#    disease3_pca_125  disease3_pca_126  disease3_pca_127  disease3_pca_128  \
# 0         -0.049646         -0.030825          0.059619          0.054251
# 1          0.065473         -0.069966          0.001386          0.022145
# 2          0.050460          0.074278          0.022300          0.048073
# 3          0.055458         -0.014474         -0.098375          0.005207
# 4          0.014293         -0.073378         -0.107103         -0.054103
#
#    disease3_pca_129  d3_clu  food_r_mean  food_r_var      skew   kurtosis
# 0         -0.027106    31.0     0.237439    0.561195  3.361275  10.718445
# 1          0.021254    46.0     0.237439    0.561195  3.361275  10.718445
# 2         -0.031466    10.0     0.237439    0.561195  3.361275  10.718445
# 3          0.010734    10.0     0.237439    0.561195  3.361275  10.718445
# 4          0.099642    14.0     0.237439    0.561195  3.361275  10.718445
#
# [5 rows x 704 columns]

# %% [markdown]
# ### 将id、标签、以及值唯一的特征名称放入列表

# %%
drop_cols = ['disease_id', 'food_id', 'related_score']

# %%
for f in data.columns:
    if data[f].nunique() < 2:
        drop_cols.append(f)

# %%
drop_cols
# Out:
# ['disease_id',
#  'food_id',
#  'related_score',
#  'N_2',
#  'N_8',
#  'N_12',
#  'N_15',
#  'N_21',
#  'N_23',
#  'N_24',
#  'N_25',
#  'N_26',
#  'N_27',
#  'N_29',
#  'N_31',
#  'N_32',
#  'N_34',
#  'N_36',
#  'N_38',
#  'N_39',
#  'N_41',
#  'N_65',
#  'N_66',
#  'N_70',
#  'N_83',
#  'N_103',
#  'N_107',
#  'N_108',
#  'N_110',
#  'N_117',
#  'N_130',
#  'N_137',
#  'N_143',
#  'N_144',
#  'N_150',
#  'N_159',
#  'N_174',
#  'N_186',
#  'N_189']

# %% [markdown]
# ### 缺失值补零
# 尝试过其他方式，比如不做处理，补充为特殊值等等，其中效果最好为补零

# %%
# test_df = data[data["related"].isnull() == True].copy().reset_index(drop=True)
train_df = data[~data["related_score"].isnull() == True].copy().reset_index(drop=True)
train_df = train_df.fillna(0)
train_df.head()
# Out:
#   food_id    disease_id  related_score  food  disease  \
# 0  food_0   disease_208              0     0      208
# 1  food_0  disease_1166              0     0     1166
# 2  food_0  disease_1418              0     0     1418
# 3  food_0    disease_76              0     0       76
# 4  food_0   disease_579              0     0      579
#
#    disease_related_score_mean  disease_related_score_std  \
# 0                    0.000000                   0.000000
# 1                    0.000000                   0.000000
# 2                    0.008621                   0.160817
# 3                    0.103448                   0.558600
# 4                    0.000000                   0.000000
#
#    disease_related_score_skew  disease_related_score_kurtosis  N_0  ...  \
# 0                    0.000000                        0.000000  0.0  ...
# 1                    0.000000                        0.000000  0.0  ...
# 2                   18.654758                      348.000000  0.0  ...
# 3                    5.820405                       34.080231  0.0  ...
# 4                    0.000000                        0.000000  0.0  ...
#
#    disease3_pca_125  disease3_pca_126  disease3_pca_127  disease3_pca_128  \
# 0         -0.049646         -0.030825          0.059619          0.054251
# 1          0.065473         -0.069966          0.001386          0.022145
# 2          0.050460          0.074278          0.022300          0.048073
# 3          0.055458         -0.014474         -0.098375          0.005207
# 4          0.014293         -0.073378         -0.107103         -0.054103
#
#    disease3_pca_129  d3_clu  food_r_mean  food_r_var      skew   kurtosis
# 0         -0.027106    31.0     0.237439    0.561195  3.361275  10.718445
# 1          0.021254    46.0     0.237439    0.561195  3.361275  10.718445
# 2         -0.031466    10.0     0.237439    0.561195  3.361275  10.718445
# 3          0.010734    10.0     0.237439    0.561195  3.361275  10.718445
# 4          0.099642    14.0     0.237439    0.561195  3.361275  10.718445
#
# [5 rows x 704 columns]

# %% [markdown]
# ### 将标签列，相关性评级>0的转变为1，做二分类

# %%
train_df['related_score'] = train_df['related_score'].apply(lambda x: 1 if x > 0 else 0)

# %% [markdown]
# ### 选择lgbm模型中特征重要性最强的五个特征进行交叉
# 由于过拟合原因，去掉了食物编码特征特征，food
# 并且去掉了加减的交叉，仅使用乘除

# %%
topn = ['N_33', 'N_198', 'N_209','N_74','N_165']
for i in range(len(topn)):
    for j in range(i + 1, len(topn)):
        # train_df[f'{topn[i]}+{topn[j]}'] = train_df[topn[i]] + train_df[topn[j]]
        # train_df[f'{topn[i]}-{topn[j]}'] = train_df[topn[i]] - train_df[topn[j]]
        train_df[f'{topn[i]}*{topn[j]}'] = train_df[topn[i]] * train_df[topn[j]]
        train_df[f'{topn[i]}/{topn[j]}'] = train_df[topn[i]] / (train_df[topn[j]]+1e-5)

# %%
feature_name = [f for f in train_df.columns if f not in drop_cols]
X_train = train_df[feature_name].reset_index(drop=True)
# X_test = test_df[feature_name].reset_index(drop=True)
y = train_df['related_score'].reset_index(drop=True)

# %%
print(len(feature_name))
print(feature_name)
# Out:
# 685
# ['food', 'disease', 'disease_related_score_mean', 'disease_related_score_std', 'disease_related_score_skew', 'disease_related_score_kurtosis', 'N_0', 'N_1', 'N_3', 'N_4', 'N_5', 'N_6', 'N_7', 'N_9', 'N_10', 'N_11', 'N_13', 'N_14', 'N_16', 'N_17', 'N_18', 'N_19', 'N_20', 'N_22', 'N_28', 'N_30', 'N_33', 'N_35', 'N_37', 'N_40', 'N_42', 'N_43', 'N_44', 'N_45', 'N_46', 'N_47', 'N_48', 'N_49', 'N_50', 'N_51', 'N_52', 'N_53', 'N_54', 'N_55', 'N_56', 'N_57', 'N_58', 'N_59', 'N_60', 'N_61', 'N_62', 'N_63', 'N_64', 'N_67', 'N_68', 'N_69', 'N_71', 'N_72', 'N_73', 'N_74', 'N_75', 'N_76', 'N_77', 'N_78', 'N_79', 'N_80', 'N_81', 'N_82', 'N_84', 'N_85', 'N_86', 'N_87', 'N_88', 'N_89', 'N_90', 'N_91', 'N_92', 'N_93', 'N_94', 'N_95', 'N_96', 'N_97', 'N_98', 'N_99', 'N_100', 'N_101', 'N_102', 'N_104', 'N_105', 'N_106', 'N_109', 'N_111', 'N_112', 'N_113', 'N_114', 'N_115', 'N_116', 'N_118', 'N_119', 'N_120', 'N_121', 'N_122', 'N_123', 'N_124', 'N_125', 'N_126', 'N_127', 'N_128', 'N_129', 'N_131', 'N_132', 'N_133', 'N_134', 'N_135', 'N_136', 'N_138', 'N_139', 'N_140', 'N_141', 'N_142', 'N_145', 'N_146', 'N_147', 'N_148', 'N_149', 'N_151', 'N_152', 'N_153', 'N_154', 'N_155', 'N_156', 'N_157', 'N_158', 'N_160', 'N_161', 'N_162', 'N_163', 'N_164', 'N_165', 'N_166', 'N_167', 'N_168', 'N_169', 'N_170', 'N_171', 'N_172', 'N_173', 'N_175', 'N_176', 'N_177', 'N_178', 'N_179', 'N_180', 'N_181', 'N_182', 'N_183', 'N_184', 'N_185', 'N_187', 'N_188', 'N_190', 'N_191', 'N_192', 'N_193', 'N_194', 'N_195', 'N_196', 'N_197', 'N_198', 'N_199', 'N_200', 'N_201', 'N_202', 'N_203', 'N_204', 'N_205', 'N_206', 'N_207', 'N_208', 'N_209', 'N_210', 'N_211', 'food_clu', 'disease1_pca_0', 'disease1_pca_1', 'disease1_pca_2', 'disease1_pca_3', 'disease1_pca_4', 'disease1_pca_5', 'disease1_pca_6', 'disease1_pca_7', 'disease1_pca_8', 'disease1_pca_9', 'disease1_pca_10', 'disease1_pca_11', 'disease1_pca_12', 'disease1_pca_13', 'disease1_pca_14', 'disease1_pca_15', 'disease1_pca_16', 'disease1_pca_17', 'disease1_pca_18', 'disease1_pca_19', 'disease1_pca_20', 'disease1_pca_21', 'disease1_pca_22', 'disease1_pca_23', 'disease1_pca_24', 'disease1_pca_25', 'disease1_pca_26', 'disease1_pca_27', 'disease1_pca_28', 'disease1_pca_29', 'disease1_pca_30', 'disease1_pca_31', 'disease1_pca_32', 'disease1_pca_33', 'disease1_pca_34', 'disease1_pca_35', 'disease1_pca_36', 'disease1_pca_37', 'disease1_pca_38', 'disease1_pca_39', 'disease1_pca_40', 'disease1_pca_41', 'disease1_pca_42', 'disease1_pca_43', 'disease1_pca_44', 'disease1_pca_45', 'disease1_pca_46', 'disease1_pca_47', 'disease1_pca_48', 'disease1_pca_49', 'disease1_pca_50', 'disease1_pca_51', 'disease1_pca_52', 'disease1_pca_53', 'disease1_pca_54', 'disease1_pca_55', 'disease1_pca_56', 'disease1_pca_57', 'disease1_pca_58', 'disease1_pca_59', 'disease1_pca_60', 'disease1_pca_61', 'disease1_pca_62', 'disease1_pca_63', 'disease1_pca_64', 'disease1_pca_65', 'disease1_pca_66', 'disease1_pca_67', 'disease1_pca_68', 'disease1_pca_69', 'disease1_pca_70', 'disease1_pca_71', 'disease1_pca_72', 'disease1_pca_73', 'disease1_pca_74', 'disease1_pca_75', 'disease1_pca_76', 'disease1_pca_77', 'disease1_pca_78', 'disease1_pca_79', 'disease1_pca_80', 'disease1_pca_81', 'disease1_pca_82', 'disease1_pca_83', 'disease1_pca_84', 'disease1_pca_85', 'disease1_pca_86', 'disease1_pca_87', 'disease1_pca_88', 'disease1_pca_89', 'disease1_pca_90', 'disease1_pca_91', 'disease1_pca_92', 'disease1_pca_93', 'disease1_pca_94', 'disease1_pca_95', 'disease1_pca_96', 'disease1_pca_97', 'disease1_pca_98', 'disease1_pca_99', 'disease1_pca_100', 'disease1_pca_101', 'disease1_pca_102', 'disease1_pca_103', 'disease1_pca_104', 'disease1_pca_105', 'disease1_pca_106', 'disease1_pca_107', 'disease1_pca_108', 'disease1_pca_109', 'disease1_pca_110', 'disease1_pca_111', 'disease1_pca_112', 'disease1_pca_113', 'disease1_pca_114', 'disease1_pca_115', 'disease1_pca_116', 'disease1_pca_117', 'disease1_pca_118', 'disease1_pca_119', 'disease1_pca_120', 'disease1_pca_121', 'disease1_pca_122 ...

# %% [markdown]
# ### 模型训练

# %%
train_pred = {}
# test_pred = {}
seeds = [222222222]
num_model_seed = 1
oof = np.zeros(X_train.shape[0])
# prediction = np.zeros(X_test.shape[0])
feat_imp_df = pd.DataFrame({'feats': feature_name, 'imp': 0})
parameters = {
    'learning_rate': 0.01,
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'metric': 'auc',
    'num_leaves': 64,
    'lambda_l1': 0.5,
    'lambda_l2': 0.5,
    'feature_fraction': 0.7,
    'bagging_fraction': 0.7,
    'bagging_freq': 5,
    'seed': 222222,
    'bagging_seed': 222222,
    'feature_fraction_seed': 222222,
    'min_data_in_leaf': 20,
    'verbose': -1, 
    'n_jobs':8
}
models_list = []
fold = 5
for model_seed in range(num_model_seed):
    print(seeds[model_seed],"--------------------------------------------------------------------------------------------")
    oof_cat = np.zeros(X_train.shape[0])
    # prediction_cat = np.zeros(X_test.shape[0])
    skf = StratifiedKFold(n_splits=fold, random_state=seeds[model_seed], shuffle=True)
    for index, (train_index, test_index) in enumerate(skf.split(X_train, y)):
        train_x, test_x, train_y, test_y = X_train[feature_name].iloc[train_index], X_train[feature_name].iloc[test_index], y.iloc[train_index], y.iloc[test_index]
        dtrain = lgb.Dataset(train_x, label=train_y)
        dval = lgb.Dataset(test_x, label=test_y)
        lgb_model = lgb.train(
            parameters,
            dtrain,
            num_boost_round=15000,
            valid_sets=[dval],
            early_stopping_rounds=100,
            verbose_eval=100 )
        models_list.append(lgb_model)
        filename = f'best_model/model_fold_{index}.pkl'
        lgb_model.save_model(filename)
        oof_cat[test_index] += lgb_model.predict(test_x,num_iteration=lgb_model.best_iteration)
        # prediction_cat += lgb_model.predict(X_test,num_iteration=lgb_model.best_iteration) / fold
        feat_imp_df['imp'] += lgb_model.feature_importance()

        del train_x
        del test_x
        del train_y
        del test_y
        del lgb_model
    oof += oof_cat / num_model_seed
    # prediction += prediction_cat / num_model_seed
gc.collect()
# Out:
# 222222222 --------------------------------------------------------------------------------------------
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.954224
# [200]	valid_0's auc: 0.961501
# [300]	valid_0's auc: 0.965942
# [400]	valid_0's auc: 0.969029
# [500]	valid_0's auc: 0.971326
# [600]	valid_0's auc: 0.972875
# [700]	valid_0's auc: 0.973914
# [800]	valid_0's auc: 0.974856
# [900]	valid_0's auc: 0.975606
# [1000]	valid_0's auc: 0.976259
# [1100]	valid_0's auc: 0.976853
# [1200]	valid_0's auc: 0.977413
# [1300]	valid_0's auc: 0.977899
# [1400]	valid_0's auc: 0.978325
# [1500]	valid_0's auc: 0.978703
# [1600]	valid_0's auc: 0.979024
# [1700]	valid_0's auc: 0.979377
# [1800]	valid_0's auc: 0.979624
# [1900]	valid_0's auc: 0.979849
# [2000]	valid_0's auc: 0.98012
# [2100]	valid_0's auc: 0.980398
# [2200]	valid_0's auc: 0.980609
# [2300]	valid_0's auc: 0.980729
# [2400]	valid_0's auc: 0.980897
# [2500]	valid_0's auc: 0.981038
# [2600]	valid_0's auc: 0.981187
# [2700]	valid_0's auc: 0.981242
# [2800]	valid_0's auc: 0.981342
# [2900]	valid_0's auc: 0.981463
# [3000]	valid_0's auc: 0.981552
# [3100]	valid_0's auc: 0.98164
# [3200]	valid_0's auc: 0.981688
# [3300]	valid_0's auc: 0.981781
# [3400]	valid_0's auc: 0.981864
# [3500]	valid_0's auc: 0.981889
# [3600]	valid_0's auc: 0.981946
# [3700]	valid_0's auc: 0.982001
# [3800]	valid_0's auc: 0.982057
# [3900]	valid_0's auc: 0.982118
# [4000]	valid_0's auc: 0.98219
# [4100]	valid_0's auc: 0.982278
# [4200]	valid_0's auc: 0.982304
# [4300]	valid_0's auc: 0.982366
# [4400]	valid_0's auc: 0.98239
# [4500]	valid_0's auc: 0.982437
# [4600]	valid_0's auc: 0.982453
# [4700]	valid_0's auc: 0.982467
# [4800]	valid_0's auc: 0.982497
# [4900]	valid_0's auc: 0.982526
# [5000]	valid_0's auc: 0.982559
# [5100]	valid_0's auc: 0.982583
# [5200]	valid_0's auc: 0.982598
# [5300]	valid_0's auc: 0.982634
# [5400]	valid_0's auc: 0.982646
# [5500]	valid_0's auc: 0.982657
# [5600]	valid_0's auc: 0.982656
# [5700]	valid_0's auc: 0.982667
# [5800]	valid_0's auc: 0.982692
# [5900]	valid_0's auc: 0.982702
# Early stopping, best iteration is:
# [5869]	valid_0's auc: 0.982721
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.951379
# [200]	valid_0's auc: 0.959804
# [300]	valid_0's auc: 0.965577
# [400]	valid_0's auc: 0.969437
# [500]	valid_0's auc: 0.971616
# [600]	valid_0's auc: 0.973122
# [700]	valid_0's auc: 0.974283
# [800]	valid_0's auc: 0.97506
# [900]	valid_0's auc: 0.975794
# [1000]	valid_0's auc: 0.976365
# [1100]	valid_0's auc: 0.976839
# [1200]	valid_0's auc: 0.977301
# [1300]	valid_0's auc: 0.977619
# [1400]	valid_0's auc: 0.977964
# [1500]	valid_0's auc: 0.978229
# [1600]	valid_0's auc: 0.978407
# [1700]	valid_0's auc: 0.9786
# [1800]	valid_0's auc: 0.978826
# [1900]	valid_0's auc: 0.979031
# [2000]	valid_0's auc: 0.979217
# [2100]	valid_0's auc: 0.979381
# [2200]	valid_0's auc: 0.979501
# [2300]	valid_0's auc: 0.979616
# [2400]	valid_0's auc: 0.979701
# [2500]	valid_0's auc: 0.979806
# [2600]	valid_0's auc: 0.9799
# [2700]	valid_0's auc: 0.979983
# [2800]	valid_0's auc: 0.980091
# [2900]	valid_0's auc: 0.980187
# [3000]	valid_0's auc: 0.980259
# [3100]	valid_0's auc: 0.980344
# [3200]	valid_0's auc: 0.980381
# [3300]	valid_0's auc: 0.980416
# [3400]	valid_0's auc: 0.980466
# [3500]	valid_0's auc: 0.980479
# [3600]	valid_0's auc: 0.980549
# [3700]	valid_0's auc: 0.980578
# [3800]	valid_0's auc: 0.980642
# [3900]	valid_0's auc: 0.980674
# [4000]	valid_0's auc: 0.980721
# [4100]	valid_0's auc: 0.980747
# [4200]	valid_0's auc: 0.980801
# [4300]	valid_0's auc: 0.980835
# [4400]	valid_0's auc: 0.980853
# [4500]	valid_0's auc: 0.980872
# [4600]	valid_0's auc: 0.980904
# [4700]	valid_0's auc: 0.980963
# [4800]	valid_0's auc: 0.980992
# [4900]	valid_0's auc: 0.981034
# [5000]	valid_0's auc: 0.981077
# [5100]	valid_0's auc: 0.981088
# [5200]	valid_0's auc: 0.981105
# [5300]	valid_0's auc: 0.981115
# Early stopping, best iteration is:
# [5278]	valid_0's auc: 0.981133
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.952782
# [200]	valid_0's auc: 0.960907
# [300]	valid_0's auc: 0.965705
# [400]	valid_0's auc: 0.969286
# [500]	valid_0's auc: 0.971567
# [600]	valid_0's auc: 0.973059
# [700]	valid_0's auc: 0.974096
# [800]	valid_0's auc: 0.974931
# [900]	valid_0's auc: 0.975622
# [1000]	valid_0's auc: 0.976197
# [1100]	valid_0's auc: 0.976713
# [1200]	valid_0's auc: 0.977125
# [1300]	valid_0's auc: 0.97756
# [1400]	valid_0's auc: 0.977993
# [1500]	valid_0's auc: 0.978302
# [1600]	valid_0's auc: 0.978537
# [1700]	valid_0's auc: 0.97869
# [1800]	valid_0's auc: 0.978947
# [1900]	valid_0's auc: 0.979202
# [2000]	valid_0's auc: 0.979447
# [2100]	valid_0's auc: 0.979605
# [2200]	valid_0's auc: 0.979795
# [2300]	valid_0's auc: 0.979947
# [2400]	valid_0's auc: 0.98005
# [2500]	valid_0's auc: 0.980162
# [2600]	valid_0's auc: 0.980182
# [2700]	valid_0's auc: 0.98027
# [2800]	valid_0's auc: 0.980384
# [2900]	valid_0's auc: 0.980503
# [3000]	valid_0's auc: 0.980578
# [3100]	valid_0's auc: 0.980633
# [3200]	valid_0's auc: 0.980666
# [3300]	valid_0's auc: 0.980753
# [3400]	valid_0's auc: 0.9808
# [3500]	valid_0's auc: 0.980858
# [3600]	valid_0's auc: 0.980922
# [3700]	valid_0's auc: 0.980967
# [3800]	valid_0's auc: 0.981052
# [3900]	valid_0's auc: 0.981078
# [4000]	valid_0's auc: 0.981132
# [4100]	valid_0's auc: 0.981149
# Early stopping, best iteration is:
# [4035]	valid_0's auc: 0.981161
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.952855
# [200]	valid_0's auc: 0.960903
# [300]	valid_0's auc: 0.966381
# [400]	valid_0's auc: 0.969932
# [500]	valid_0's auc: 0.972305
# [600]	valid_0's auc: 0.973832
# [700]	valid_0's auc: 0.974991
# [800]	valid_0's auc: 0.975857
# [900]	valid_0's auc: 0.976655
# [1000]	valid_0's auc: 0.977243
# [1100]	valid_0's auc: 0.977821
# [1200]	valid_0's auc: 0.978263
# [1300]	valid_0's auc: 0.978628
# [1400]	valid_0's auc: 0.979023
# [1500]	valid_0's auc: 0.979269
# [1600]	valid_0's auc: 0.979581
# [1700]	valid_0's auc: 0.979775
# [1800]	valid_0's auc: 0.979987
# [1900]	valid_0's auc: 0.980181
# [2000]	valid_0's auc: 0.980332
# [2100]	valid_0's auc: 0.980495
# [2200]	valid_0's auc: 0.980607
# [2300]	valid_0's auc: 0.980779
# [2400]	valid_0's auc: 0.98092
# [2500]	valid_0's auc: 0.981079
# [2600]	valid_0's auc: 0.981143
# [2700]	valid_0's auc: 0.981261
# [2800]	valid_0's auc: 0.981382
# [2900]	valid_0's auc: 0.981476
# [3000]	valid_0's auc: 0.981572
# [3100]	valid_0's auc: 0.981655
# [3200]	valid_0's auc: 0.981709
# [3300]	valid_0's auc: 0.981783
# [3400]	valid_0's auc: 0.98183
# [3500]	valid_0's auc: 0.981835
# [3600]	valid_0's auc: 0.981892
# [3700]	valid_0's auc: 0.98191
# [3800]	valid_0's auc: 0.981967
# [3900]	valid_0's auc: 0.982016
# [4000]	valid_0's auc: 0.982073
# [4100]	valid_0's auc: 0.982098
# [4200]	valid_0's auc: 0.982151
# [4300]	valid_0's auc: 0.982159
# [4400]	valid_0's auc: 0.982189
# [4500]	valid_0's auc: 0.98222
# [4600]	valid_0's auc: 0.982242
# [4700]	valid_0's auc: 0.982262
# [4800]	valid_0's auc: 0.982272
# Early stopping, best iteration is:
# [4735]	valid_0's auc: 0.982278
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.952756
# [200]	valid_0's auc: 0.960696
# [300]	valid_0's auc: 0.965953
# [400]	valid_0's auc: 0.969649
# [500]	valid_0's auc: 0.971837
# [600]	valid_0's auc: 0.973453
# [700]	valid_0's auc: 0.974709
# [800]	valid_0's auc: 0.975581
# [900]	valid_0's auc: 0.976226
# [1000]	valid_0's auc: 0.976855
# [1100]	valid_0's auc: 0.977401
# [1200]	valid_0's auc: 0.97781
# [1300]	valid_0's auc: 0.978174
# [1400]	valid_0's auc: 0.978431
# [1500]	valid_0's auc: 0.978705
# [1600]	valid_0's auc: 0.978929
# [1700]	valid_0's auc: 0.979182
# [1800]	valid_0's auc: 0.979404
# [1900]	valid_0's auc: 0.979571
# [2000]	valid_0's auc: 0.979797
# [2100]	valid_0's auc: 0.979957
# [2200]	valid_0's auc: 0.980181
# [2300]	valid_0's auc: 0.98029
# [2400]	valid_0's auc: 0.980421
# [2500]	valid_0's auc: 0.980545
# [2600]	valid_0's auc: 0.980619
# [2700]	valid_0's auc: 0.980748
# [2800]	valid_0's auc: 0.98088
# [2900]	valid_0's auc: 0.980988
# [3000]	valid_0's auc: 0.981085
# [3100]	valid_0's auc: 0.981104
# [3200]	valid_0's auc: 0.981196
# [3300]	valid_0's auc: 0.981243
# [3400]	valid_0's auc: 0.981332
# [3500]	valid_0's auc: 0.981396
# [3600]	valid_0's auc: 0.981422
# [3700]	valid_0's auc: 0.981444
# [3800]	valid_0's auc: 0.981485
# [3900]	valid_0's auc: 0.981559
# [4000]	valid_0's auc: 0.981583
# [4100]	valid_0's auc: 0.981603
# Early stopping, best iteration is:
# [4085]	valid_0's auc: 0.981614
# 702

# %%
y_r = train_answer['related']

# %%
y_r = [1 if x >= 1 else 0 for x in y ]
sum(y_r)/len(y_r)
# Out:
# 0.09947329774915982

# %%
len(y_r)
# Out:
# 141636

# %%
import sklearn 
y_pred = (oof >= 0.5).astype(int)
auc_value = sklearn.metrics.roc_auc_score(y_r, oof)
f1_vlaue = sklearn.metrics.f1_score(y_r, y_pred)


print('total_score:', (auc_value+f1_vlaue)/2)
print("auc_score:", auc_value)
print("f1_score:", f1_vlaue)
# Out:
# total_score: 0.9001269980980433
# auc_score: 0.9817119688831416
# f1_score: 0.8185420273129449

# %% [markdown]
# total_score: 0.9001269980980433
# auc_score: 0.9817119688831416
# f1_score: 0.8185420273129449
